# %% [markdown]
# <a href="https://colab.research.google.com/github/rachanabn20/CMIR-2025-Code-Mixed-Information-Retrieval/blob/main/CMIR_2025_Code_Mixed_Information_Retrieval.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python-terrier
# Out:
# Collecting python-terrier
#   Downloading python_terrier-0.13.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from python-terrier) (2.2.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from python-terrier) (10.7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from python-terrier) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from python-terrier) (2.32.4)
# Collecting ir-datasets>=0.3.2 (from python-terrier)
#   Downloading ir_datasets-0.5.11-py3-none-any.whl.metadata (12 kB)
# Collecting pyjnius>=1.4.2 (from python-terrier)
#   Downloading pyjnius-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.2.18)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.15.3)
# Collecting ir-measures>=0.3.1 (from python-terrier)
#   Downloading ir_measures-0.3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting pytrec-eval-terrier>=0.5.3 (from python-terrier)
#   Downloading pytrec_eval_terrier-0.5.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (984 bytes)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from python-terrier) (3.1.6)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from python-terrier) (0.14.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from python-terrier) (0.3.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from python-terrier) (1.5.1)
# Collecting chest (from python-terrier)
#   Downloading chest-0.2.3.tar.gz (9.6 kB)
#   Preparing metadata (setup.py) ... done
# Collecting lz4 (from python-terrier)
#   Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.8 kB)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (4.13.4)
# Collecting inscriptis>=2.2.0 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading inscriptis-2.6.0-py3-none-any.whl.metadata (25 kB)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (5.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (6.0.2)
# Collecting trec-car-tools>=2.5.4 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading trec_car_tools-2.6-py3-none-any.whl.metadata (640 bytes)
# Collecting warc3-wet>=0.2.3 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading warc3_wet-0.2.5-py3-none-any.whl.metadata (2.2 kB)
# Collecting warc3-wet-clueweb09>=0.2.5 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading warc3-wet-clueweb09-0.2.5.tar.gz (17 kB)
#   Preparing metadata (setup.py) ... done
# Collecting zlib-state>=0.1.3 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading zlib_state-0.1.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting ijson>=3.1.3 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading ijson-3.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (21 kB)
# Collecting unlzw3>=0.2.1 (from ir-datasets>=0.3.2->python-terrier)
#   Downloading unlzw3-0.2.3-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: pyarrow>=16.1.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier) (19.0.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier) (2025.6.15)
# Collecting heapdict (from chest->python-terrier)
#   Downloading HeapDict-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->python-terrier) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->python-terrier) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier) (2025.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->python-terrier) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from statsmodels->python-terrier) (25.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (4.14.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->python-terrier) (1.17.0)
# Collecting cbor>=1.0.0 (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier)
#   Downloading cbor-1.0.0.tar.gz (20 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->python-terrier) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->python-terrier) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->python-terrier) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->python-terrier) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->python-terrier) (2024.2.0)
# Downloading python_terrier-0.13.1-py3-none-any.whl (167 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.5/167.5 kB 5.6 MB/s eta 0:00:00
# Downloading ir_datasets-0.5.11-py3-none-any.whl (866 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 866.1/866.1 kB 23.4 MB/s eta 0:00:0000:01
# Downloading ir_measures-0.3.7-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 3.8 MB/s eta 0:00:00
# Downloading lz4-4.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 49.1 MB/s eta 0:00:00
# Downloading pyjnius-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.3 MB/s eta 0:00:00
# Downloading pytrec_eval_terrier-0.5.7-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.0/288.0 kB 16.0 MB/s eta 0:00:00
# Downloading ijson-3.4.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (134 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.0/135.0 kB 8.3 MB/s eta 0:00:00
# Downloading inscriptis-2.6.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.4 MB/s eta 0:00:00
# Downloading trec_car_tools-2.6-py3-none-any.whl (8.4 kB)
# Downloading unlzw3-0.2.3-py3-none-any.whl (6.7 kB)
# Downloading warc3_wet-0.2.5-py3-none-any.whl (18 kB)
# Downloading zlib_state-0.1.9-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21 kB)
# Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Building wheels for collected packages: chest, warc3-wet-clueweb09, cbor
#   Building wheel for chest (setup.py) ... done
#   Created wheel for chest: filename=chest-0.2.3-py3-none-any.whl size=7611 sha256=35d9236bc7a258abb7f94ab0ca550e55dec98c3d1d31e4bf1d02eb71526764a1
#   Stored in directory: /root/.cache/pip/wheels/48/57/13/28831e81239278141f874ee9b7d6d5490a1b1191c2d07a3e73
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Created wheel for warc3-wet-clueweb09: filename=warc3_wet_clueweb09-0.2.5-py3-none-any.whl size=18919 sha256=ba8f8fb37ecdb84d516958b024d5cdba2e589b1a650545e634ada71814c9b3dc
#   Stored in directory: /root/.cache/pip/wheels/63/f9/dc/2dd16d3330e327236e4d407941975c42d5159d200cdb7922d8
#   Building wheel for cbor (setup.py) ... done
#   Created wheel for cbor: filename=cbor-1.0.0-cp311-cp311-linux_x86_64.whl size=53933 sha256=7a6542621c34798d159a24e28dfe23478bed6d9cc83a67130457e09e7a382723
#   Stored in directory: /root/.cache/pip/wheels/21/6b/45/0c34253b1af07d1d9dc524f6d44d74a6b191c43152e6aaf641
# Successfully built chest warc3-wet-clueweb09 cbor
# Installing collected packages: warc3-wet-clueweb09, warc3-wet, pyjnius, heapdict, cbor, zlib-state, unlzw3, pytrec-eval-terrier, lz4, ijson, chest, ir-measures, inscriptis, trec-car-tools, ir-datasets, python-terrier
# Successfully installed cbor-1.0.0 chest-0.2.3 heapdict-1.0.1 ijson-3.4.0 inscriptis-2.6.0 ir-datasets-0.5.11 ir-measures-0.3.7 lz4-4.4.4 pyjnius-1.6.1 python-terrier-0.13.1 pytrec-eval-terrier-0.5.7 trec-car-tools-2.6 unlzw3-0.2.3 warc3-wet-0.2.5 warc3-wet-clueweb09-0.2.5 zlib-state-0.1.9

# %%
import pyterrier as pt
pt.init()
# Out:
# terrier-assemblies 5.11 jar-with-dependencies not found, downloading to /root/.pyterrier...
# https://repo1.maven.org/maven2/org/terrier/terrier-assemblies/5.11/terrier-assemblies-5.11-jar-with-dependencies.jar: 100%|██████████| 99.6M/99.6M [00:00<00:00, 254MB/s]
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /root/.pyterrier...
# https://repo1.maven.org/maven2/org/terrier/terrier-python-helper/0.0.8/terrier-python-helper-0.0.8.jar: 100%|██████████| 36.6k/36.6k [00:00<00:00, 12.8MB/s]
# Done
# Java started and loaded: pyterrier.java, pyterrier.terrier.java [version=5.11 (build: craig.macdonald 2025-01-13 21:29), helper_version=0.0.8]
# /tmp/ipykernel_36/2516926211.py:2: DeprecationWarning: Call to deprecated method pt.init(). Deprecated since version 0.11.0.
# java is now started automatically with default settings. To force initialisation early, run:
# pt.java.init() # optional, forces java initialisation
#   pt.init()

# %%
# accessing files from my drive - HLS

files = ["/kaggle/input/cmir-2025/Baseline_Corpus.trec"]
indexer = pt.TRECCollectionIndexer(f"./index", overwrite = True, stemmer = None, stopwords=None)
indexref = indexer.index(files)
index = pt.IndexFactory.of(indexref)

# %%
tf_idf = pt.BatchRetrieve(index, wmodel="TF_IDF")
bm25 = pt.BatchRetrieve(index, wmodel="BM25")
pl2 = pt.BatchRetrieve(index, wmodel="PL2")
InL2 = pt.BatchRetrieve(index, wmodel="InL2")
Hiemstra_LM = pt.BatchRetrieve(index, wmodel="Hiemstra_LM")
# Out:
# /tmp/ipykernel_36/1013159242.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   tf_idf = pt.BatchRetrieve(index, wmodel="TF_IDF")
# /tmp/ipykernel_36/1013159242.py:2: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   bm25 = pt.BatchRetrieve(index, wmodel="BM25")
# /tmp/ipykernel_36/1013159242.py:3: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   pl2 = pt.BatchRetrieve(index, wmodel="PL2")
# /tmp/ipykernel_36/1013159242.py:4: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   InL2 = pt.BatchRetrieve(index, wmodel="InL2")
# /tmp/ipykernel_36/1013159242.py:5: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   Hiemstra_LM = pt.BatchRetrieve(index, wmodel="Hiemstra_LM")

# %%
topics = pt.io.read_topics('/kaggle/input/cmir-2025/Train_query_20_Roman.trec')
qrels = pt.io.read_qrels('/kaggle/input/cmir-2025/QRels_Train_20.txt')

# %%
result = pt.Experiment([tf_idf, bm25, pl2, InL2, Hiemstra_LM],
                       topics,
                       qrels,
                       eval_metrics=["map", "recip_rank", "ndcg", "P_5", "P_10"], verbose = True)
print(result)
# Out:
# pt.Experiment: 100%|██████████| 5/5 [00:04<00:00,  1.06system/s]
#                        name       map  recip_rank      ndcg   P_5   P_10
# 0       TerrierRetr(TF_IDF)  0.173530    0.654553  0.393390  0.35  0.250
# 1         TerrierRetr(BM25)  0.175802    0.662623  0.397553  0.34  0.250
# 2          TerrierRetr(PL2)  0.165005    0.643877  0.384670  0.33  0.235
# 3         TerrierRetr(InL2)  0.180464    0.651930  0.403353  0.35  0.275
# 4  TerrierRetr(Hiemstra_LM)  0.246725    0.801860  0.483592  0.50  0.360

# %%
test_queries = pt.io.read_topics("/kaggle/input/cmir-2025/test_query_30.trec")
test_queries.head()
# Out:
#   qid                                              query
# 0  26  hi hyderabad e rapid antigen test kothay kora ...
# 1  27  hello everyone i need urgent information regar...
# 2  28  hi all can anyone tell me any adhar center nea...
# 3  29  amar thakuma kolkata theke aamar kache shift k...
# 4  30  last time apollo theke rtpcr test koriyechilam...

# %%
import joblib
joblib.dump(bm25, "bm25_model.joblib")
# Out:
# ['bm25_model.joblib']

# %%
import pyterrier as pt
import joblib
import pandas as pd

# Initialize PyTerrier
if not pt.started():
    pt.init()

# Load test queries
test_queries = pt.io.read_topics("/kaggle/input/cmir-2025/test_query_30.trec")

# Load trained model
model = joblib.load("/kaggle/working/bm25_model.joblib")

# Generate predictions
results = model.transform(test_queries)

# Format required columns
results = results[["qid", "docno", "rank", "score"]]
results["tag"] = "bm25"

# Save predictions to CSV
results.to_csv("test1_predictions.csv", index=False)
# Out:
# /tmp/ipykernel_36/3184126084.py:6: DeprecationWarning: Call to deprecated function (or staticmethod) started. (use pt.java.started() instead) -- Deprecated since version 0.11.0.
#   if not pt.started():

# %%
res_file = bm25.transform(topics)
print(res_file)
# Out:
#       qid   docid   docno  rank      score  \
# 0       1  106544  106545     0  30.984167
# 1       1   78143   78144     1  21.911458
# 2       1   33223   33224     2  21.359212
# 3       1   60457   60458     3  19.093987
# 4       1   71411   71412     4  18.751333
# ...    ..     ...     ...   ...        ...
# 19995  25   41694   41695   995  16.131297
# 19996  25     822     823   996  16.130693
# 19997  25   68755   68756   997  16.129350
# 19998  25   60021   60022   998  16.127682
# 19999  25   65075   65076   999  16.125956
#
#                                                    query
# 0      hyderabad to howrah kono train ki diyeche ba d...
# 1      hyderabad to howrah kono train ki diyeche ba d...
# 2      hyderabad to howrah kono train ki diyeche ba d...
# 3      hyderabad to howrah kono train ki diyeche ba d...
# 4      hyderabad to howrah kono train ki diyeche ba d...
# ...                                                  ...
# 19995  need an information regarding sastho sathi car...
# 19996  need an information regarding sastho sathi car...
# 19997  need an information regarding sastho sathi car...
# 19998  need an information regarding sastho sathi car...
# 19999  need an information regarding sastho sathi car...
#
# [20000 rows x 6 columns]

# %% [markdown]
# ------------------------------------------------------------------

# %%
files = ["/kaggle/input/cmir-2025/Baseline_Corpus.trec"]
topics = pt.io.read_topics('/kaggle/input/cmir-2025/Train_query_20_Roman.trec')
qrels = pt.io.read_qrels('/kaggle/input/cmir-2025/QRels_Train_20.txt')
test_queries = pt.io.read_topics("/kaggle/input/cmir-2025/test_query_30.trec")

# %%
indexer = pt.TRECCollectionIndexer("/content/index", overwrite = True)  # added overwrite - True as it was giving error
indexref = indexer.index(files)
index = pt.IndexFactory.of(indexref)
# Out:
# 11:28:50.479 [main] WARN org.terrier.structures.indexing.Indexer -- Adding an empty document to the index (145) - further warnings are suppressed
# 11:28:58.127 [main] WARN org.terrier.structures.indexing.Indexer -- Indexed 95 empty documents

# %%
bm25       = pt.BatchRetrieve(index, wmodel="BM25")
dph        = pt.BatchRetrieve(index, wmodel="DPH")
pl2        = pt.BatchRetrieve(index, wmodel="PL2")
tfidf      = pt.BatchRetrieve(index, wmodel="TF_IDF")
ql         = pt.BatchRetrieve(index, wmodel="Hiemstra_LM")
dirichlet  = pt.BatchRetrieve(index, wmodel="DirichletLM")
dlh13      = pt.BatchRetrieve(index, wmodel="DLH13")
ifb2       = pt.BatchRetrieve(index, wmodel="IFB2")
# Out:
# /tmp/ipykernel_36/3384829923.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   bm25       = pt.BatchRetrieve(index, wmodel="BM25")
# /tmp/ipykernel_36/3384829923.py:2: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   dph        = pt.BatchRetrieve(index, wmodel="DPH")
# /tmp/ipykernel_36/3384829923.py:3: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   pl2        = pt.BatchRetrieve(index, wmodel="PL2")
# /tmp/ipykernel_36/3384829923.py:4: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   tfidf      = pt.BatchRetrieve(index, wmodel="TF_IDF")
# /tmp/ipykernel_36/3384829923.py:5: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   ql         = pt.BatchRetrieve(index, wmodel="Hiemstra_LM")
# /tmp/ipykernel_36/3384829923.py:6: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   dirichlet  = pt.BatchRetrieve(index, wmodel="DirichletLM")
# /tmp/ipykernel_36/3384829923.py:7: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   dlh13      = pt.BatchRetrieve(index, wmodel="DLH13")
# /tmp/ipykernel_36/3384829923.py:8: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   ifb2       = pt.BatchRetrieve(index, wmodel="IFB2")

# %%
all_models = [tfidf, bm25, pl2, dph, ql, dirichlet, dlh13, ifb2]
model_names = ["TF_IDF", "BM25", "PL2", "DPH", "Hiemstra_LM", "DirichletLM", "DLH13", "IFB2"]

result = pt.Experiment(
    all_models,
    topics,
    qrels,
    eval_metrics=["map", "recip_rank", "ndcg", "P_5", "P_10"],
    names=model_names,
    verbose=True
)

print(result)
# Out:
# pt.Experiment: 100%|██████████| 8/8 [00:05<00:00,  1.40system/s]
#           name       map  recip_rank      ndcg   P_5   P_10
# 0       TF_IDF  0.203710    0.707828  0.435052  0.37  0.275
# 1         BM25  0.206274    0.711735  0.439723  0.37  0.270
# 2          PL2  0.198143    0.699313  0.425535  0.36  0.260
# 3          DPH  0.158178    0.690650  0.407897  0.30  0.235
# 4  Hiemstra_LM  0.265494    0.831812  0.513845  0.51  0.370
# 5  DirichletLM  0.212906    0.766310  0.502181  0.39  0.300
# 6        DLH13  0.199714    0.748438  0.438409  0.36  0.285
# 7         IFB2  0.227289    0.725407  0.463754  0.41  0.305

# %%
from pyterrier.apply import by_query


fused_model = bm25 + dirichlet + ql

fused_results = fused_model(topics)


result_fused = pt.Experiment(
    [fused_model],
    topics,
    qrels,
    eval_metrics=["map", "recip_rank", "ndcg", "P_5", "P_10"],
    names=["Fused_BM25_Dirichlet_QL"],
    verbose=True
)

print(result_fused)
# Out:
# pt.Experiment: 100%|██████████| 1/1 [00:02<00:00,  2.12s/system]
#                       name      map  recip_rank     ndcg   P_5  P_10
# 0  Fused_BM25_Dirichlet_QL  0.26357    0.827083  0.53679  0.51  0.38

# %%
test_results = fused_model.transform(test_queries)
test_results = test_results[["qid", "docno", "rank", "score"]]
test_results["tag"] = "RRF_Fusion"
test_results.to_csv("test2_predictions.csv", index=False)

# %% [markdown]
# ---------------------------------------------

# %%
# !pip install pyterrier_t5
# Out:
# Collecting pyterrier_t5
#   Downloading pyterrier_t5-0.1.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: python-terrier>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from pyterrier_t5) (0.13.1)
# Requirement already satisfied: transformers>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from pyterrier_t5) (4.52.4)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from pyterrier_t5) (2.6.0+cu124)
# Requirement already satisfied: sentencepiece>=0.1.95 in /usr/local/lib/python3.11/dist-packages (from pyterrier_t5) (0.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (1.26.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (2.2.3)
# Requirement already satisfied: more-itertools in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (10.7.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (2.32.4)
# Requirement already satisfied: ir-datasets>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (0.5.11)
# Requirement already satisfied: pyjnius>=1.4.2 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (1.6.1)
# Requirement already satisfied: deprecated in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (1.2.18)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (1.15.3)
# Requirement already satisfied: ir-measures>=0.3.1 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (0.3.7)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (0.5.7)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (3.1.6)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (0.14.4)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (0.3.8)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (1.5.1)
# Requirement already satisfied: chest in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (0.2.3)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.11/dist-packages (from python-terrier>=0.9.0->pyterrier_t5) (4.4.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from transformers>=4.0.0->pyterrier_t5) (3.18.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.0.0->pyterrier_t5) (0.33.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.0.0->pyterrier_t5) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.0.0->pyterrier_t5) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.0.0->pyterrier_t5) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.0.0->pyterrier_t5) (0.21.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers>=4.0.0->pyterrier_t5) (0.5.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->pyterrier_t5) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->pyterrier_t5) (3.5)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->pyterrier_t5) (2025.5.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch->pyterrier_t5)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch->pyterrier_t5)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch->pyterrier_t5)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch->pyterrier_t5)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch->pyterrier_t5)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch->pyterrier_t5)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch->pyterrier_t5)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch->pyterrier_t5)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch->pyterrier_t5)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->pyterrier_t5) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->pyterrier_t5) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->pyterrier_t5) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch->pyterrier_t5)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->pyterrier_t5) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->pyterrier_t5) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->pyterrier_t5) (1.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0,>=0.30.0->transformers>=4.0.0->pyterrier_t5) (1.1.5)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (4.13.4)
# Requirement already satisfied: inscriptis>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (2.6.0)
# Requirement already satisfied: lxml>=4.5.2 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (5.4.0)
# Requirement already satisfied: trec-car-tools>=2.5.4 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (2.6)
# Requirement already satisfied: warc3-wet>=0.2.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (3.4.0)
# Requirement already satisfied: unlzw3>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (0.2.3)
# Requirement already satisfied: pyarrow>=16.1.0 in /usr/local/lib/python3.11/dist-packages (from ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (19.0.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier>=0.9.0->pyterrier_t5) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier>=0.9.0->pyterrier_t5) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier>=0.9.0->pyterrier_t5) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier>=0.9.0->pyterrier_t5) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier>=0.9.0->pyterrier_t5) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->python-terrier>=0.9.0->pyterrier_t5) (2.4.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier>=0.9.0->pyterrier_t5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier>=0.9.0->pyterrier_t5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier>=0.9.0->pyterrier_t5) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->python-terrier>=0.9.0->pyterrier_t5) (2025.6.15)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.11/dist-packages (from chest->python-terrier>=0.9.0->pyterrier_t5) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated->python-terrier>=0.9.0->pyterrier_t5) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->python-terrier>=0.9.0->pyterrier_t5) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier>=0.9.0->pyterrier_t5) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier>=0.9.0->pyterrier_t5) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->python-terrier>=0.9.0->pyterrier_t5) (2025.2)
# Requirement already satisfied: patsy>=0.5.6 in /usr/local/lib/python3.11/dist-packages (from statsmodels->python-terrier>=0.9.0->pyterrier_t5) (1.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (2.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->python-terrier>=0.9.0->pyterrier_t5) (1.17.0)
# Requirement already satisfied: cbor>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier>=0.9.0->pyterrier_t5) (1.0.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->python-terrier>=0.9.0->pyterrier_t5) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->python-terrier>=0.9.0->pyterrier_t5) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->python-terrier>=0.9.0->pyterrier_t5) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->python-terrier>=0.9.0->pyterrier_t5) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->python-terrier>=0.9.0->pyterrier_t5) (2024.2.0)
# Downloading pyterrier_t5-0.1.0-py3-none-any.whl (13 kB)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 80.3 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 68.5 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 36.9 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 8.4 MB/s eta 0:00:000:00:0100:01
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 11.7 MB/s eta 0:00:0000:0100:01
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.1 MB/s eta 0:00:00:00:0100:01
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 60.2 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, pyterrier_t5
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 pyterrier_t5-0.1.0

# %%
import pyterrier as pt
import torch
from pyterrier_t5 import MonoT5ReRanker
# Out:
# 2025-07-24 11:30:52.430634: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753356652.780444      36 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1753356652.883726      36 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
bm25 = pt.BatchRetrieve(index, wmodel="BM25", verbose=True)
dirichlet = pt.BatchRetrieve(index, wmodel="DirichletLM", verbose=True)
pl2 = pt.BatchRetrieve(index, wmodel="PL2", verbose=True)
# Out:
# /tmp/ipykernel_36/3678423896.py:1: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   bm25 = pt.BatchRetrieve(index, wmodel="BM25", verbose=True)
# /tmp/ipykernel_36/3678423896.py:2: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   dirichlet = pt.BatchRetrieve(index, wmodel="DirichletLM", verbose=True)
# /tmp/ipykernel_36/3678423896.py:3: DeprecationWarning: Call to deprecated class BatchRetrieve. (use pt.terrier.Retriever() instead) -- Deprecated since version 0.11.0.
#   pl2 = pt.BatchRetrieve(index, wmodel="PL2", verbose=True)

# %%
rm3 = bm25 >> pt.rewrite.RM3(index) >> bm25

# %%
reranker = MonoT5ReRanker("castorini/monot5-base-msmarco")
# Out:
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# config.json: 0.00B [00:00, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
class DropInvalidDocs(pt.Transformer):
    def __init__(self, valid_docnos, valid_docids):
        self.valid_docnos = valid_docnos
        self.valid_docids = valid_docids

    def transform(self, input_df):
        print(f"Before filtering: {len(input_df)} rows")
        input_df = input_df.dropna(subset=["docno", "docid"])
        input_df = input_df[
            input_df["docno"].astype(str).str.strip() != ""
        ]
        input_df = input_df[
            input_df["docno"].isin(self.valid_docnos) &
            input_df["docid"].isin(self.valid_docids)
        ]
        print(f"After filtering: {len(input_df)} rows")
        return input_df

# %%
class SafeTextLoader(pt.Transformer):
    def __init__(self, index):
        self.index = index
        self.meta = index.getMetaIndex()

    def transform(self, input_df):
        if "docid" not in input_df.columns:
            raise ValueError("Missing 'docid' in input")

        input_df = input_df.dropna(subset=["docid"])
        input_df["docid"] = input_df["docid"].astype(int)
        docids = input_df["docid"].tolist()

        try:
            texts = self.meta.getItems("text", docids)
            input_df["text"] = texts
        except Exception as e:
            print("Error loading text from MetaIndex:", str(e))
            input_df["text"] = ""

        return input_df

# %%
meta = index.getMetaIndex()
num_docs = index.getCollectionStatistics().getNumberOfDocuments()

valid_docnos = set(str(x) for x in meta.getItems("docno", list(range(num_docs))))
valid_docids = set(range(num_docs))

doc_filter = DropInvalidDocs(valid_docnos, valid_docids)
text_loader = SafeTextLoader(index)
lexical_fusion= bm25+ dirichlet + pl2 +rm3
hybrid_pipeline = (
    bm25 + dirichlet + pl2 + rm3
) >> doc_filter >> text_loader >> reranker

# %%
eval_metrics = ["map", "recip_rank", "ndcg", "P_5", "P_10"]
results = pt.Experiment(
    [bm25, dirichlet, pl2, lexical_fusion, hybrid_pipeline],
    topics,
    qrels,
    eval_metrics=eval_metrics,
    names=["BM25", "Dirichlet", "PL2", "Lexical","HybridFusion+BERT"]
)
print(results)
# Out:
# TerrierRetr(BM25):   0%|          | 0/20 [00:00<?, ?q/s]
# TerrierRetr(BM25):  10%|█         | 2/20 [00:00<00:01, 15.41q/s]
# TerrierRetr(BM25):  25%|██▌       | 5/20 [00:00<00:00, 19.27q/s]
# TerrierRetr(BM25):  35%|███▌      | 7/20 [00:00<00:00, 17.97q/s]
# TerrierRetr(BM25):  45%|████▌     | 9/20 [00:00<00:00, 17.62q/s]
# TerrierRetr(BM25):  60%|██████    | 12/20 [00:00<00:00, 18.57q/s]
# TerrierRetr(BM25):  75%|███████▌  | 15/20 [00:00<00:00, 18.20q/s]
# TerrierRetr(BM25):  85%|████████▌ | 17/20 [00:00<00:00, 17.92q/s]
# TerrierRetr(BM25): 100%|██████████| 20/20 [00:01<00:00, 18.15q/s]
#
# TerrierRetr(DirichletLM):   0%|          | 0/20 [00:00<?, ?q/s]
# TerrierRetr(DirichletLM):  10%|█         | 2/20 [00:00<00:01, 17.84q/s]
# TerrierRetr(DirichletLM):  20%|██        | 4/20 [00:00<00:00, 17.55q/s]
# TerrierRetr(DirichletLM):  30%|███       | 6/20 [00:00<00:00, 17.52q/s]
# TerrierRetr(DirichletLM):  45%|████▌     | 9/20 [00:00<00:00, 18.60q/s]
# TerrierRetr(DirichletLM):  55%|█████▌    | 11/20 [00:00<00:00, 17.60q/s]
# TerrierRetr(DirichletLM):  65%|██████▌   | 13/20 [00:00<00:00, 17.13q/s]
# TerrierRetr(DirichletLM):  75%|███████▌  | 15/20 [00:00<00:00, 17.69q/s]
# TerrierRetr(DirichletLM):  85%|████████▌ | 17/20 [00:00<00:00, 17.92q/s]
# TerrierRetr(DirichletLM): 100%|██████████| 20/20 [00:01<00:00, 17.89q/s]
#
# TerrierRetr(PL2):   0%|          | 0/20 [00:00<?, ?q/s]
# TerrierRetr(PL2):  10%|█         | 2/20 [00:00<00:01, 17.83q/s]
# TerrierRetr(PL2):  20%|██        | 4/20 [00:00<00:00, 17.35q/s]
# TerrierRetr(PL2):  35%|███▌      | 7/20 [00:00<00:00, 19.49q/s]
# TerrierRetr(PL2):  45%|████▌     | 9/20 [00:00<00:00, 18.51q/s]
# TerrierRetr(PL2):  60%|██████    | 12/20 [00:00<00:00, 20.64q/s]
# TerrierRetr(PL2):  80%|████████  | 16/20 [00:00<00:00, 25.15q/s]
# TerrierRetr(PL2): 100%|██████████| 20/20 [00:00<00:00, 22.90q/s]
# TerrierRetr(BM25): 100%|██████████| 20/20 [00:00<00:00, 35.02q/s]
# TerrierRetr(DirichletLM): 100%|██████████| 20/20 [00:00<00:00, 34.05q/s]
# TerrierRetr(PL2): 100%|██████████| 20/20 [00:00<00:00, 32.55q/s]
# TerrierRetr(BM25): 100%|██████████| 20/20 [00:00<00:00, 30.95q/s]
# TerrierRetr(BM25): 100%|██████████| 20/20 [00:00<00:00, 29.11q/s]
# TerrierRetr(BM25): 100%|██████████| 20/20 [00:00<00:00, 33.50q/s]
# TerrierRetr(DirichletLM): 100%|██████████| 20/20 [00:01<00:00, 19.12q/s]
# TerrierRetr(PL2): 100%|██████████| 20/20 [00:00<00:00, 32.36q/s]
# TerrierRetr(BM25): 100%|██████████| 20/20 [00:00<00:00, 32.34q/s]
# TerrierRetr(BM25): 100%|██████████| 20/20 [00:00<00:00, 31.89q/s]
# Before filtering: 44201 rows
# After filtering: 20000 rows
# monoT5:   0%|          | 0/5000 [00:00<?, ?batches/s]Passing a tuple of `past_key_values` is deprecated and will be removed in Transformers v4.48.0. You should pass an instance of `EncoderDecoderCache` instead, e.g. `past_key_values=EncoderDecoderCache.from_legacy_cache(past_key_values)`.
# monoT5: 100%|██████████| 5000/5000 [1:11:50<00:00,  1.16batches/s]
#                 name       map  recip_rank      ndcg   P_5   P_10
# 0               BM25  0.206274    0.711735  0.439723  0.37  0.270
# 1          Dirichlet  0.212906    0.766310  0.502181  0.39  0.300
# 2                PL2  0.198143    0.699313  0.425535  0.36  0.260
# 3            Lexical  0.252724    0.694416  0.517156  0.48  0.360
# 4  HybridFusion+BERT  0.009483    0.027478  0.186251  0.00  0.005

# %%
test_results = fused_model.transform(test_queries)
test_results = test_results[["qid", "docno", "rank", "score"]]
test_results["tag"] = "Hybrid"
test_results.to_csv("test3_predictions.csv", index=False)
